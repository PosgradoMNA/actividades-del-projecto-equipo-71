# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo-71/blob/main/Semana_3_Actividad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ciencia y analítica de datos
# # Semana 3 - Actividad 1
# # Bases de datos: Fundamentos, selección y limpieza.
#
# * Equipo: Ignacio Antonio Quintero Chávez, Francisco Xavier Bastidas Moreno.
# * Matrículas: A01794419, A01794188.
# * Profesor: Jobish Vallikavungal Devassia.
# * Fecha: 4 de octubre del 2022.

# %% [markdown]
# ### Parte 1: Fundamentos de base de datos

# %% [markdown]
# **1. Fundamentos de bases de datos y para ciencia de datos.**
#
# Una base de datos es una colección organizada de información estructurada que normalmente está almacenada en un sistema informático. Una base de datos generalmente está controlada por un sistema de administración de bases de datos (DataBase Management System).
#
# Una de las actividades de un científico de datos es interactuar con bases de datos en la mayoría de los proyectos a trabajar. A veces se necesitará crear desde cero y otras veces solo se necesitará saber como comunicarse con una base de datos ya existente.

# %% [markdown]
# **2. Fundamentos de almacenes de datos (Data Warehouse) para ciencia de datos.**
#
# Un almacén de datos es un sistema que permite almacenar, analizar e interpretar datos para facilitar una mejor toma de decisiones. Los almacenes de datos están destinados únicamente a realizar consultas y análisis y, a menudo, contienen grandes cantidades de datos históricos.
#
# Los aspectos importantes en la construcción de un almacén de datos eficaz incluyen la definición de la información que es fundamental para la organización y la identificación de las fuentes de la información. Los datos se extraen periódicamente de varias aplicaciones internas como ventas, marketing y finanzas; aplicaciones de interfaz de cliente; así como sistemas de socios externos.

# %% [markdown]
# **Bibliografía consultada**
#
#
# *  Metwalli, S. A. (2020, septiembre 27). *Databases 101: Introduction to databases for data scientists. Towards Data Science*. Recuperado el 1 de octubre de 2022, de https://towardsdatascience.com/databases-101-introduction-to-databases-for-data-scientists-ee18c9f0785d
# *   *What is a data warehouse?* (s/f). Oracle.com. Recuperado el 1 de octubre de 2022, de https://www.oracle.com/database/what-is-a-data-warehouse/

# %% [markdown]
# ### Parte 2: Selección y limpieza de datos en Python

# %%
# Import the libraries
import pandas as pd
import numpy as np

# %% [markdown]
# El primer paso es cargar y leer el data set que se proporcionó para trabajar. Se guarda en una variable llamada 'dataset'.

# %%
dataset = "https://raw.githubusercontent.com/PosgradoMNA/Actividades_Aprendizaje-/main/default%20of%20credit%20card%20clients.csv"

# %% [markdown]
# Posteriormente, se crea un data frame para leer el archivo CSV con el que se trabajará, se asigna en 'dataframe' y se imprime.

# %%
# Save the names of the columns in a list called names
names = ["ID", "amount_credit", "gender", "education", "marital_status", "age", "hist_sep", "hist_aug", "hist_jul", "hist_jun", "hist_may", "hist_apr", "amt_bill_sep", "amt_bill_aug", "amt_bill_jul", "amt_bill_jun", "amt_bill_may", "amt_bill_apr", "paid_amt_sep", "paid_amt_aug", "paid_amt_jul", "paid_amt_jun", "paid_amt_may", "paid_amt_apr", "Y"]
# Rename the column names using names.
# Delete the default index using index_col = 0
# Remove the header using header = 0. This will allow our columns names to be the headers
dataframe = pd.read_csv(dataset, names = names, index_col = 0, header = 0)
# Print the data frame
dataframe
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %%
# Print our columns names
dataframe.columns
# Out:
# Index(['amount_credit', 'gender', 'education', 'marital_status', 'age',
#        'hist_sep', 'hist_aug', 'hist_jul', 'hist_jun', 'hist_may', 'hist_apr',
#        'amt_bill_sep', 'amt_bill_aug', 'amt_bill_jul', 'amt_bill_jun',
#        'amt_bill_may', 'amt_bill_apr', 'paid_amt_sep', 'paid_amt_aug',
#        'paid_amt_jul', 'paid_amt_jun', 'paid_amt_may', 'paid_amt_apr', 'Y'],
#       dtype='object')

# %% [markdown]
# El contenido de nuestro data frame es el siguiente:
#
# This research employed a binary variable, default payment (Yes = 1, No = 0), as the response variable. This study reviewed the literature and used the following 23 variables as explanatory variables:
#
#
# *   amount_credit: Amount of the given credit (NT dollar - it includes both the individual consumer credit and his/her family (supplementary) credit.
# *   gender: 1 = male; 2 = female.
# * education: 1 = graduate school; 2 = university; 3 = high school; 4 = others.
# * marital_status: 1 = married; 2 = single; 3 = others).
# * age: year.
# * hist_sep: Repayment status in September, 2005.
# * hist_aug: Repayment status in August, 2005.
# * hist_jul: Repayment status in July, 2005.
# * hist_jun: Repayment status in June, 2005.
# * hist_may: Repayment status in May, 2005.
# * hist_apr: Repayment status in April, 2005.
# * amt_bill_sep: Amount of bill statement in September, 2005.
# * amt_bill_aug: Amount of bill statement in August, 2005.
# * amt_bill_jul: Amount of bill statement in July, 2005.
# * amt_bill_jun: Amount of bill statement in June, 2005.
# * amt_bill_may: Amount of bill statement in May, 2005.
# * amt_bill_apr: Amount of bill statement in April, 2005.
# * paid_amt_sep: Amount paid in September ,2005.
# * paid_amt_aug: Amount paid in August ,2005.
# * paid_amt_jul: Amount paid in July ,2005.
# * paid_amt_jun: Amount paid in June ,2005.
# * paid_amt_may: Amount paid in May ,2005.
# * paid_amt_apr: Amount paid in April ,2005.
# * Y: Default probability.

# %%
# Print the first 10 rows
first_10 = dataframe.head(10)
first_10
# Out:
#     amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1           20000     2.0        2.0             1.0  24.0       2.0
# 2          120000     2.0        2.0             2.0  26.0      -1.0
# 3           90000     2.0        2.0             2.0  34.0       0.0
# 4           50000     2.0        2.0             1.0  37.0       0.0
# 5           50000     1.0        2.0             1.0  57.0      -1.0
# 6           50000     1.0        1.0             2.0  37.0       0.0
# 7          500000     1.0        1.0             2.0  29.0       0.0
# 8          100000     2.0        2.0             2.0  23.0       0.0
# 9          140000     2.0        3.0             1.0  28.0       0.0
# 10          20000     1.0        3.0             2.0  35.0      -2.0
#
#     hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  amt_bill_may  \
# ID                                          ...
# 1        2.0      -1.0      -1.0      -2.0  ...           0.0           0.0
# ...

# %% [markdown]
# El siguiente paso es entender la información que contiene el data frame. Cuantas columnas, cuantos registros, y los tipos de cada dato por columna.

# %%
# Get the dataframe information
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   amount_credit   30000 non-null  int64
#  1   gender          29999 non-null  float64
#  2   education       29998 non-null  float64
#  3   marital_status  29998 non-null  float64
#  4   age             29995 non-null  float64
#  5   hist_sep        29997 non-null  float64
#  6   hist_aug        29995 non-null  float64
#  7   hist_jul        29993 non-null  float64
#  8   hist_jun        29991 non-null  float64
#  9   hist_may        29984 non-null  float64
#  10  hist_apr        29986 non-null  float64
#  11  amt_bill_sep    29989 non-null  float64
#  12  amt_bill_aug    29989 non-null  float64
#  13  amt_bill_jul    29987 non-null  float64
#  14  amt_bill_jun    29985 non-null  float64
#  15  amt_bill_may    29983 non-null  float64
# ...

# %% [markdown]
# Adicionalmente, para saber el tipo de dato de cada columna se puede utilizar el siguiente comando.

# %%
# Get the dataframe data types
dataframe.dtypes
# Out:
# amount_credit       int64
# gender            float64
# education         float64
# marital_status    float64
# age               float64
# hist_sep          float64
# hist_aug          float64
# hist_jul          float64
# hist_jun          float64
# hist_may          float64
# hist_apr          float64
# amt_bill_sep      float64
# amt_bill_aug      float64
# amt_bill_jul      float64
# amt_bill_jun      float64
# amt_bill_may      float64
# amt_bill_apr      float64
# paid_amt_sep      float64
# paid_amt_aug      float64
# paid_amt_jul      float64
# paid_amt_jun      float64
# paid_amt_may      float64
# paid_amt_apr      float64
# Y                 float64
# dtype: object

# %% [markdown]
# Validamos si existen datos perdidos.

# %%
dataframe.isnull().values.any()
# Out:
# True

# %% [markdown]
# Anteriormente, al obtener la información del data frame se podía verificar que columnas tienen datos perdidos. Otra forma de saberlo es mediante el siguiente paso.

# %%
dataframe.isnull().any()
# Out:
# amount_credit     False
# gender             True
# education          True
# marital_status     True
# age                True
# hist_sep           True
# hist_aug           True
# hist_jul           True
# hist_jun           True
# hist_may           True
# hist_apr           True
# amt_bill_sep       True
# amt_bill_aug       True
# amt_bill_jul       True
# amt_bill_jun       True
# amt_bill_may       True
# amt_bill_apr       True
# paid_amt_sep       True
# paid_amt_aug       True
# paid_amt_jul       True
# paid_amt_jun       True
# paid_amt_may       True
# paid_amt_apr       True
# Y                  True
# dtype: bool

# %% [markdown]
# ### Solución 1

# %% [markdown]
# Como parte de buenas prácticas, se genera una copia del data frame original para trabajar.

# %%
df_copy = dataframe.copy()
df_copy
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Descartamos las observaciones con valores faltantes en el siguiente paso.

# %%
df_copy.dropna(inplace = True)

# %% [markdown]
# Validamos si existen datos perdidos.

# %%
df_copy.isna().values.any()
# Out:
# False

# %%
df_copy
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Según la documentación, si falta algún dato en todo el conjunto de datos, se elimina la fila correspondiente.

# %% [markdown]
# Creamos nuevamente una copia del data frame para trabajar.

# %%
df_copy_2 = dataframe.copy()
df_copy_2
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# En el siguiente paso se eliminan todas las columnas donde falte por lo menos un elemento.

# %%
# Reference: 'axis = 1' refers to columns, and 'axis = 0' refers to rows.
df_copy_2.dropna(axis = 1)
# Out:
#        amount_credit
# ID
# 1              20000
# 2             120000
# 3              90000
# 4              50000
# 5              50000
# ...              ...
# 29996         220000
# 29997         150000
# 29998          30000
# 29999          80000
# 30000          50000
#
# [30000 rows x 1 columns]

# %% [markdown]
# Se eliminan 22 columnas de las 23 que contiene el data set, por lo tanto no es una buena estrategia.

# %% [markdown]
# Creamos otra copia del data frame original para trabajar el siguiente paso.

# %%
df_copy_3 = dataframe.copy()
df_copy_3
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# El siguiente paso es una alternativa utilizando un threshold. Dejamos solo las filas con *x* número de valores que no sean *nan*.

# %%
# To maintain a row, we need at least 4 nan values.
# 'inplace = True' modifies the original data frame
df_copy_3.dropna(thresh = 4, inplace = True)
df_copy_3
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# ### Solución 2

# %% [markdown]
# Cargamos nuevamente la base de datos.

# %%
data_input = "https://raw.githubusercontent.com/PosgradoMNA/Actividades_Aprendizaje-/main/default%20of%20credit%20card%20clients.csv"

# %%
# Save the names of the columns in a list called names
names = ["ID", "amount_credit", "gender", "education", "marital_status", "age", "hist_sep", "hist_aug", "hist_jul", "hist_jun", "hist_may", "hist_apr", "amt_bill_sep", "amt_bill_aug", "amt_bill_jul", "amt_bill_jun", "amt_bill_may", "amt_bill_apr", "paid_amt_sep", "paid_amt_aug", "paid_amt_jul", "paid_amt_jun", "paid_amt_may", "paid_amt_apr", "Y"]
# Rename the column names using names.
# Delete the default index using index_col = 0
# Remove the header using header = 0. This will allow our columns names to be the headers
dataframe = pd.read_csv(data_input, names = names, index_col = 0, header = 0)
# Print the data frame
dataframe
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Se genera una copia del data frame para trabajar.

# %%
df_copy = dataframe.copy()
df_copy
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Se obtiene el promedio de la primer columna en el siguiente paso.

# %%
df_m = df_copy.amount_credit.mean()
df_m
# Out:
# 167484.32266666667

# %% [markdown]
# En el siguiente paso, los valores de la columna 'amount_credit' que aparezcan como N/A, se modificarán con el promedio que calculamos anteriormente.

# %%
df_copy['amount_credit'].fillna(value = df_m, inplace = True)
df_copy
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Se repite el mismo proceso, con la columna 'gender', y en esta ocasión se calcula la mediana.

# %%
df_copy['gender'].fillna(value = df_copy.gender.median(), inplace = True)
df_copy
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Obtenemos la moda de la columna 'amount_credit'.

# %%
df_mo = df_copy.amount_credit.mode()
df_mo
# Out:
# 0    50000
# dtype: int64

# %% [markdown]
# Posteriormente, ocupamos los valores faltantes de esta columna con el valor que obtuvimos al sacar la moda.

# %%
df_copy['amount_credit'].fillna(value = df_mo[0], inplace = True)
df_copy
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Comprobamos valores faltantes, como lo hicimos al principio del ejercicio.

# %%
df_copy.isnull().values.any()
# Out:
# True

# %% [markdown]
# Nuevamente, creamos una copia del data frame original.

# %%
df_copy_2 = dataframe.copy()
df_copy_2
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Eliminamos las filas con valores N/A en las columnas con las que trabajamos.

# %%
df_copy_2.dropna(subset=['amount_credit', 'gender'], inplace = True)
df_copy_2
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Generamos una nueva copia del data frame original.

# %%
df_copy_3 = dataframe.copy()

# %% [markdown]
# En el siguiente paso obtenemos la moda de la columna 'amount_credit'.
#
# Posteriormente, generamos un diccionario donde ocupamos la moda y promedio para las dos primeras columnas.

# %%
df_copy_3.amount_credit.mode()[0]
# Out:
# 50000

# %%
dict1 = {"amount_credit": df_copy_3.amount_credit.mode()[0], "gender": df_copy_3["amount_credit"].mean()}
print(dict1)
# Out:
# {'amount_credit': 50000, 'gender': 167484.32266666667}

# %%
df_copy_3.amount_credit.fillna(df_copy_3.amount_credit.mode()[0], inplace = True)
df_copy_3.gender.fillna(df_copy_3.mean(), inplace = True)
df_copy_3
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# ¿Cuándo es una mediana mejor en comparación con la media?

# %%
df_copy_4 = dataframe.copy()
df_copy
# Out:
#        amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1              20000     2.0        2.0             1.0  24.0       2.0
# 2             120000     2.0        2.0             2.0  26.0      -1.0
# 3              90000     2.0        2.0             2.0  34.0       0.0
# 4              50000     2.0        2.0             1.0  37.0       0.0
# 5              50000     1.0        2.0             1.0  57.0      -1.0
# ...              ...     ...        ...             ...   ...       ...
# 29996         220000     1.0        3.0             1.0  39.0       0.0
# 29997         150000     1.0        3.0             2.0  43.0      -1.0
# 29998          30000     1.0        2.0             2.0  37.0       4.0
# 29999          80000     1.0        3.0             1.0  41.0       1.0
# 30000          50000     1.0        2.0             1.0  46.0       0.0
#
#        hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  \
# ...

# %% [markdown]
# Seleccionar las columnas de la base de datos.

# %%
df_copy_4.columns
# Out:
# Index(['amount_credit', 'gender', 'education', 'marital_status', 'age',
#        'hist_sep', 'hist_aug', 'hist_jul', 'hist_jun', 'hist_may', 'hist_apr',
#        'amt_bill_sep', 'amt_bill_aug', 'amt_bill_jul', 'amt_bill_jun',
#        'amt_bill_may', 'amt_bill_apr', 'paid_amt_sep', 'paid_amt_aug',
#        'paid_amt_jul', 'paid_amt_jun', 'paid_amt_may', 'paid_amt_apr', 'Y'],
#       dtype='object')

# %%
df_copy_4.columns.sort_values()
# Out:
# Index(['Y', 'age', 'amount_credit', 'amt_bill_apr', 'amt_bill_aug',
#        'amt_bill_jul', 'amt_bill_jun', 'amt_bill_may', 'amt_bill_sep',
#        'education', 'gender', 'hist_apr', 'hist_aug', 'hist_jul', 'hist_jun',
#        'hist_may', 'hist_sep', 'marital_status', 'paid_amt_apr',
#        'paid_amt_aug', 'paid_amt_jul', 'paid_amt_jun', 'paid_amt_may',
#        'paid_amt_sep'],
#       dtype='object')

# %%
df_copy_4.loc[2:5, "hist_may":"amt_bill_jun"]
# Out:
#     hist_may  hist_apr  amt_bill_sep  amt_bill_aug  amt_bill_jul  amt_bill_jun
# ID
# 2        0.0       2.0        2682.0        1725.0        2682.0        3272.0
# 3        0.0       0.0       29239.0       14027.0       13559.0       14331.0
# 4        0.0       0.0       46990.0       48233.0       49291.0       28314.0
# 5        0.0       0.0        8617.0        5670.0       35835.0       20940.0

# %%
my_list = ["amt_bill_jun", "amt_bill_may", "amt_bill_apr"]
df_copy_4.loc[2:5, my_list]
# Out:
#     amt_bill_jun  amt_bill_may  amt_bill_apr
# ID
# 2         3272.0        3455.0        3261.0
# 3        14331.0       14948.0       15549.0
# 4        28314.0       28959.0       29547.0
# 5        20940.0       19146.0       19131.0

# %%
df_copy_4.iloc[2:5, [1, 2, 3]]
# Out:
#     gender  education  marital_status
# ID
# 3      2.0        2.0             2.0
# 4      2.0        2.0             1.0
# 5      1.0        2.0             1.0

# %%
df_copy.iloc[0:5, [0, 2, 5]]
# Out:
#     amount_credit  education  hist_sep
# ID
# 1           20000        2.0       2.0
# 2          120000        2.0      -1.0
# 3           90000        2.0       0.0
# 4           50000        2.0       0.0
# 5           50000        2.0      -1.0

# %%
df_copy_4.columns
# Out:
# Index(['amount_credit', 'gender', 'education', 'marital_status', 'age',
#        'hist_sep', 'hist_aug', 'hist_jul', 'hist_jun', 'hist_may', 'hist_apr',
#        'amt_bill_sep', 'amt_bill_aug', 'amt_bill_jul', 'amt_bill_jun',
#        'amt_bill_may', 'amt_bill_apr', 'paid_amt_sep', 'paid_amt_aug',
#        'paid_amt_jul', 'paid_amt_jun', 'paid_amt_may', 'paid_amt_apr', 'Y'],
#       dtype='object')

# %%
for i in df_copy_4.columns:
  print(i)
# Out:
# amount_credit
# gender
# education
# marital_status
# age
# hist_sep
# hist_aug
# hist_jul
# hist_jun
# hist_may
# hist_apr
# amt_bill_sep
# amt_bill_aug
# amt_bill_jul
# amt_bill_jun
# amt_bill_may
# amt_bill_apr
# paid_amt_sep
# paid_amt_aug
# paid_amt_jul
# paid_amt_jun
# paid_amt_may
# paid_amt_apr
# Y

# %%
df_copy_4.head()
# Out:
#     amount_credit  gender  education  marital_status   age  hist_sep  \
# ID
# 1           20000     2.0        2.0             1.0  24.0       2.0
# 2          120000     2.0        2.0             2.0  26.0      -1.0
# 3           90000     2.0        2.0             2.0  34.0       0.0
# 4           50000     2.0        2.0             1.0  37.0       0.0
# 5           50000     1.0        2.0             1.0  57.0      -1.0
#
#     hist_aug  hist_jul  hist_jun  hist_may  ...  amt_bill_jun  amt_bill_may  \
# ID                                          ...
# 1        2.0      -1.0      -1.0      -2.0  ...           0.0           0.0
# 2        2.0       0.0       0.0       0.0  ...        3272.0        3455.0
# 3        0.0       0.0       0.0       0.0  ...       14331.0       14948.0
# 4        0.0       0.0       0.0       0.0  ...       28314.0       28959.0
# 5        0.0      -1.0       0.0       0.0  ...       20940.0       19146.0
#
# ...

# %%
df_copy_4.amount_credit.unique()
# Out:
# array([  20000,  120000,   90000,   50000,  500000,  100000,  140000,
#         200000,  260000,  630000,   70000,  250000,  320000,  360000,
#         180000,  130000,  450000,   60000,  230000,  160000,  280000,
#          10000,   40000,  210000,  150000,  380000,  310000,  400000,
#          80000,  290000,  340000,  300000,   30000,  240000,  470000,
#         480000,  350000,  330000,  110000,  420000,  170000,  370000,
#         270000,  220000,  190000,  510000,  460000,  440000,  410000,
#         490000,  390000,  580000,  600000,  620000,  610000,  700000,
#         670000,  680000,  430000,  550000,  540000, 1000000,  530000,
#         710000,  560000,  520000,  750000,  640000,   16000,  570000,
#         590000,  660000,  720000,  327680,  740000,  800000,  760000,
#         690000,  650000,  780000,  730000])

# %%
df_copy_4.groupby(["age", "hist_sep"]).size()
# Out:
# age   hist_sep
# 21.0  -2.0         1
#       -1.0         7
#        0.0        47
#        1.0         4
#        2.0         7
#                   ..
# 73.0   0.0         1
# 74.0   0.0         1
# 75.0   0.0         2
#        1.0         1
# 79.0   0.0         1
# Length: 383, dtype: int64

# %%
df_copy_4[["hist_aug", "hist_jul"]].value_counts()
# Out:
# hist_aug  hist_jul
#  0.0       0.0        14071
# -1.0      -1.0         4670
# -2.0      -2.0         3377
#  2.0       2.0         2302
#            0.0         1117
#  0.0       2.0          837
# -1.0       0.0          571
#  0.0      -1.0          548
# -1.0      -2.0          402
# -2.0      -1.0          401
# -1.0       2.0          385
#  2.0      -1.0          307
#  3.0       2.0          290
#  0.0      -2.0          239
#  2.0       3.0           88
#  4.0       3.0           82
#  2.0      -2.0           55
#  0.0       3.0           27
#  5.0       4.0           25
#  2.0       7.0           25
#  3.0       3.0           24
#  2.0       4.0           22
#  7.0       6.0           20
# -1.0       3.0           19
#  4.0       4.0           16
#  6.0       5.0           12
#  1.0      -2.0           12
#  3.0       4.0            9
#  1.0      -1.0            9
#  2.0       5.0            6
#  1.0       1.0            4
#  0.0       4.0            4
# ...

# %% [markdown]
# # Parte 3. Preparación de los datos

# %% [markdown]
# **¿Qué datos considero mas importantes? ¿Por qué?**
#
# La media, debido a que nos ayudó a llenar los datos faltantes.

# %% [markdown]
# **¿Se eliminaron o reemplazaron datos nulos? ¿Qué se hizo y por qué?**
#
# Si, se eliminaron datos que no representan un porcentaje alto del total. Con la media se logró llenar esos datos.

# %% [markdown]
# **¿Es necesario ordenar los datos para el análisis? Sí / No / ¿Por qué?**
#
# Si, es recomendable explorar los datos que tiene el data frame. Ordenarlos y limpiarlos para que el proceso de limpieza y extracción sean más sencillos.

# %% [markdown]
# **¿Existen problemas de formato que deban solucionar antes del proceso de modelado? Sí / No / Por qué.**
#
# Es recomendable eliminar los registros que tengan valores NaN. Otro paso que consideré necesario desde un principio fue cambiar el nombre de las columnas debido a que proporciona más claridad al momento de realizar la limpieza.

# %% [markdown]
# **¿Qué ajustes se realizaron en el proceso de limpieza de datos (agregar, integrar, eliminar, modificar registros (filas), cambiar atributos (columnas)?**
#
# Se cambiaron el nombre de las columnas desde un inicio para trabajar. Otro ajuste realizado fue el de quitar las filas con valores NaN, y reemplazar valores erróneos con la media obtenida.
